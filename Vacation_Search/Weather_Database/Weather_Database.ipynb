# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
import time
import csv
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
coordinates = list(zip(lats, lngs))
len(coordinates)
# Out:
# 2000

# %%
# Create list of unique cities
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)     
len(cities)
# Out:
# 723

# %%
# API call to Open Weather Map
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []

# break for 60 second for every 50 records
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i>=50):
        set_count +=1
        record_count = 1
        time.sleep(60)

# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khani
# Processing Record 2 of Set 1 | atar
# Processing Record 3 of Set 1 | yerbogachen
# Processing Record 4 of Set 1 | kamaishi
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | meulaboh
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | yulara
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | pathein
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | zemetchino
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | dunedin
# Processing Record 18 of Set 1 | natal
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | iskateley
# Processing Record 22 of Set 1 | maniitsoq
# Processing Record 23 of Set 1 | tebingtinggi
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | iquitos
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | nanortalik
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | ahipara
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | gizo
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | misratah
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | moundou
# Processing Record 43 of Set 1 | sinop
# Processing Record 44 of Set 1 | cairns
# Processing Record 45 of Set 1 | cayenne
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | guerrero negro
# Processing Record 49 of Set 1 | pinheiro machado
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | aneho
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | aykhal
# Processing Record 6 of Set 2 | pangkalanbuun
# Processing Record 7 of Set 2 | nouadhibou
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | mitsamiouli
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | escanaba
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | shakawe
# Processing Record 16 of Set 2 | san joaquin
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | nanakuli
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | lagoa
# Processing Record 22 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | alor setar
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | itarema
# Processing Record 30 of Set 2 | port-gentil
# Processing Record 31 of Set 2 | salinopolis
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | sitka
# Processing Record 34 of Set 2 | hay river
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | huilong
# Processing Record 37 of Set 2 | sao gabriel da cachoeira
# Processing Record 38 of Set 2 | ponazyrevo
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | marzuq
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | turmalina
# Processing Record 47 of Set 2 | kudahuvadhoo
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | muroto
# Processing Record 50 of Set 2 | husavik
# Processing Record 1 of Set 3 | laichingen
# Processing Record 2 of Set 3 | batagay
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | troitsko-pechorsk
# Processing Record 5 of Set 3 | yelizovo
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | sur
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 3 | sabaudia
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | hengshui
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | alta floresta
# Processing Record 16 of Set 3 | severo-kurilsk
# Processing Record 17 of Set 3 | nabire
# Processing Record 18 of Set 3 | bandarbeyla
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | carman
# Processing Record 21 of Set 3 | staryy nadym
# Processing Record 22 of Set 3 | boshan
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | tatawin
# Processing Record 28 of Set 3 | hambantota
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | buraydah
# Processing Record 31 of Set 3 | la ronge
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | hearst
# Processing Record 35 of Set 3 | kisangani
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | bluefields
# Processing Record 38 of Set 3 | matara
# Processing Record 39 of Set 3 | byron bay
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | santa cruz de tenerife
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 3 | teahupoo
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | mayo
# Processing Record 48 of Set 3 | halifax
# Processing Record 49 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 3 | cape town
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | fortuna
# Processing Record 3 of Set 4 | makakilo city
# Processing Record 4 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | hirado
# Processing Record 8 of Set 4 | inyonga
# Processing Record 9 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 4 | iquique
# Processing Record 11 of Set 4 | kjollefjord
# Processing Record 12 of Set 4 | kuppam
# Processing Record 13 of Set 4 | camacha
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | nelson bay
# Processing Record 16 of Set 4 | stornoway
# Processing Record 17 of Set 4 | kifri
# Processing Record 18 of Set 4 | margate
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | ambilobe
# Processing Record 21 of Set 4 | port lincoln
# Processing Record 22 of Set 4 | northam
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | bowen
# Processing Record 25 of Set 4 | micheweni
# Processing Record 26 of Set 4 | bud
# Processing Record 27 of Set 4 | tomiya
# Processing Record 28 of Set 4 | bredasdorp
# Processing Record 29 of Set 4 | cidreira
# Processing Record 30 of Set 4 | lata
# Processing Record 31 of Set 4 | imbituba
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | ekhabi
# Processing Record 34 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 4 | ayame
# Processing Record 36 of Set 4 | krasnoselkup
# Processing Record 37 of Set 4 | cururupu
# Processing Record 38 of Set 4 | aksarka
# Processing Record 39 of Set 4 | samarai
# Processing Record 40 of Set 4 | isiro
# Processing Record 41 of Set 4 | lakitelek
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | galesong
# Processing Record 44 of Set 4 | fergus falls
# Processing Record 45 of Set 4 | trat
# Processing Record 46 of Set 4 | grand gaube
# Processing Record 47 of Set 4 | mount isa
# Processing Record 48 of Set 4 | esperance
# Processing Record 49 of Set 4 | okhotsk
# Processing Record 50 of Set 4 | chiari
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | fort saint james
# Processing Record 3 of Set 5 | kuala terengganu
# Processing Record 4 of Set 5 | mercedes
# Processing Record 5 of Set 5 | rio gallegos
# Processing Record 6 of Set 5 | tibati
# Processing Record 7 of Set 5 | provideniya
# Processing Record 8 of Set 5 | touba
# Processing Record 9 of Set 5 | qabis
# City not found. Skipping...
# Processing Record 10 of Set 5 | antalaha
# Processing Record 11 of Set 5 | naujamiestis
# Processing Record 12 of Set 5 | taltal
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | mukhen
# Processing Record 15 of Set 5 | te anau
# Processing Record 16 of Set 5 | asau
# Processing Record 17 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 5 | ponta do sol
# Processing Record 19 of Set 5 | kutoarjo
# Processing Record 20 of Set 5 | touros
# Processing Record 21 of Set 5 | saint-francois
# Processing Record 22 of Set 5 | narsaq
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | teya
# Processing Record 25 of Set 5 | ulagan
# Processing Record 26 of Set 5 | viedma
# Processing Record 27 of Set 5 | murmashi
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | barrow
# Processing Record 31 of Set 5 | beringovskiy
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | padang
# Processing Record 34 of Set 5 | pevek
# Processing Record 35 of Set 5 | xining
# Processing Record 36 of Set 5 | rudbar
# Processing Record 37 of Set 5 | rafaela
# Processing Record 38 of Set 5 | moberly
# Processing Record 39 of Set 5 | alto araguaia
# Processing Record 40 of Set 5 | phan thiet
# Processing Record 41 of Set 5 | chapais
# Processing Record 42 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | verkhnevilyuysk
# Processing Record 44 of Set 5 | palmer
# Processing Record 45 of Set 5 | aras
# Processing Record 46 of Set 5 | faanui
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | borujerd
# Processing Record 49 of Set 5 | rawlins
# Processing Record 50 of Set 5 | egvekinot
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | nemuro
# Processing Record 3 of Set 6 | quatre cocos
# Processing Record 4 of Set 6 | marinette
# Processing Record 5 of Set 6 | herat
# Processing Record 6 of Set 6 | mundo nuevo
# Processing Record 7 of Set 6 | shubarshi
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | yangcun
# Processing Record 10 of Set 6 | paita
# Processing Record 11 of Set 6 | hovd
# Processing Record 12 of Set 6 | aklavik
# Processing Record 13 of Set 6 | coahuayana
# Processing Record 14 of Set 6 | baruun-urt
# Processing Record 15 of Set 6 | midyat
# Processing Record 16 of Set 6 | sari
# Processing Record 17 of Set 6 | kaeo
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | porto walter
# Processing Record 20 of Set 6 | adrar
# Processing Record 21 of Set 6 | ouranopolis
# City not found. Skipping...
# Processing Record 22 of Set 6 | uribia
# Processing Record 23 of Set 6 | necochea
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | vigrestad
# Processing Record 26 of Set 6 | pyu
# Processing Record 27 of Set 6 | flin flon
# Processing Record 28 of Set 6 | christchurch
# Processing Record 29 of Set 6 | takoradi
# Processing Record 30 of Set 6 | kakogawa
# Processing Record 31 of Set 6 | qiongshan
# Processing Record 32 of Set 6 | mareeba
# Processing Record 33 of Set 6 | banjar
# Processing Record 34 of Set 6 | ligayan
# Processing Record 35 of Set 6 | silver city
# Processing Record 36 of Set 6 | victoria
# Processing Record 37 of Set 6 | florence
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | brookings
# Processing Record 40 of Set 6 | shingu
# Processing Record 41 of Set 6 | adre
# Processing Record 42 of Set 6 | esfarayen
# Processing Record 43 of Set 6 | angoche
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | sinnamary
# Processing Record 46 of Set 6 | gat
# Processing Record 47 of Set 6 | booue
# Processing Record 48 of Set 6 | anito
# Processing Record 49 of Set 6 | kavieng
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | takestan
# Processing Record 2 of Set 7 | san jose
# Processing Record 3 of Set 7 | artesia
# Processing Record 4 of Set 7 | chernyshevskiy
# Processing Record 5 of Set 7 | bundaberg
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | awjilah
# Processing Record 8 of Set 7 | tahta
# Processing Record 9 of Set 7 | lavrentiya
# Processing Record 10 of Set 7 | mkushi
# Processing Record 11 of Set 7 | hermiston
# Processing Record 12 of Set 7 | marystown
# Processing Record 13 of Set 7 | peace river
# Processing Record 14 of Set 7 | buta
# Processing Record 15 of Set 7 | pangody
# Processing Record 16 of Set 7 | mariinsk
# Processing Record 17 of Set 7 | martapura
# Processing Record 18 of Set 7 | kochevo
# Processing Record 19 of Set 7 | alofi
# Processing Record 20 of Set 7 | pengcheng
# Processing Record 21 of Set 7 | cockburn town
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | tautira
# Processing Record 24 of Set 7 | hokitika
# Processing Record 25 of Set 7 | raudeberg
# Processing Record 26 of Set 7 | tucupita
# Processing Record 27 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 28 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 7 | bitkine
# Processing Record 30 of Set 7 | englewood
# Processing Record 31 of Set 7 | sisimiut
# Processing Record 32 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 7 | ondangwa
# Processing Record 34 of Set 7 | mae hong son
# Processing Record 35 of Set 7 | daru
# Processing Record 36 of Set 7 | ulundi
# Processing Record 37 of Set 7 | deputatskiy
# Processing Record 38 of Set 7 | bugene
# Processing Record 39 of Set 7 | tyumentsevo
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | pontes e lacerda
# Processing Record 42 of Set 7 | majene
# Processing Record 43 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 7 | klaksvik
# Processing Record 45 of Set 7 | chimoio
# Processing Record 46 of Set 7 | manuk mangkaw
# Processing Record 47 of Set 7 | wanaka
# Processing Record 48 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 49 of Set 7 | isangel
# Processing Record 50 of Set 7 | allende
# Processing Record 1 of Set 8 | mecca
# Processing Record 2 of Set 8 | fort smith
# Processing Record 3 of Set 8 | tacuarembo
# Processing Record 4 of Set 8 | redmond
# Processing Record 5 of Set 8 | sola
# Processing Record 6 of Set 8 | tours
# Processing Record 7 of Set 8 | torres
# Processing Record 8 of Set 8 | yeppoon
# Processing Record 9 of Set 8 | kruisfontein
# Processing Record 10 of Set 8 | opuwo
# Processing Record 11 of Set 8 | rawson
# Processing Record 12 of Set 8 | anadyr
# Processing Record 13 of Set 8 | tezu
# Processing Record 14 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 8 | rey bouba
# Processing Record 16 of Set 8 | umm kaddadah
# Processing Record 17 of Set 8 | sabang
# Processing Record 18 of Set 8 | axim
# Processing Record 19 of Set 8 | port elizabeth
# Processing Record 20 of Set 8 | bidar
# Processing Record 21 of Set 8 | arraial do cabo
# Processing Record 22 of Set 8 | pangnirtung
# Processing Record 23 of Set 8 | kasongo-lunda
# Processing Record 24 of Set 8 | lompoc
# Processing Record 25 of Set 8 | vanavara
# Processing Record 26 of Set 8 | kanniyakumari
# Processing Record 27 of Set 8 | jurm
# Processing Record 28 of Set 8 | desna
# Processing Record 29 of Set 8 | zirgan
# Processing Record 30 of Set 8 | havre-saint-pierre
# Processing Record 31 of Set 8 | tomatlan
# Processing Record 32 of Set 8 | dondo
# Processing Record 33 of Set 8 | namibe
# Processing Record 34 of Set 8 | north platte
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | ust-kulom
# Processing Record 37 of Set 8 | porto novo
# Processing Record 38 of Set 8 | batemans bay
# Processing Record 39 of Set 8 | la union
# Processing Record 40 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 8 | los llanos de aridane
# Processing Record 42 of Set 8 | minna
# Processing Record 43 of Set 8 | dosso
# Processing Record 44 of Set 8 | namatanai
# Processing Record 45 of Set 8 | arnsberg
# Processing Record 46 of Set 8 | chimbote
# Processing Record 47 of Set 8 | tura
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | niihama
# Processing Record 50 of Set 8 | dubbo
# Processing Record 1 of Set 9 | samfya
# Processing Record 2 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 9 | celestun
# Processing Record 4 of Set 9 | mahibadhoo
# Processing Record 5 of Set 9 | pisco
# Processing Record 6 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | barranquilla
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | penzance
# Processing Record 11 of Set 9 | ponta delgada
# Processing Record 12 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 9 | pidhorodne
# Processing Record 14 of Set 9 | koslan
# Processing Record 15 of Set 9 | kirkwall
# Processing Record 16 of Set 9 | zhaotong
# Processing Record 17 of Set 9 | mullingar
# Processing Record 18 of Set 9 | haines junction
# Processing Record 19 of Set 9 | kampene
# Processing Record 20 of Set 9 | morondava
# Processing Record 21 of Set 9 | vostok
# Processing Record 22 of Set 9 | sistranda
# Processing Record 23 of Set 9 | ciudad valles
# Processing Record 24 of Set 9 | nesbyen
# Processing Record 25 of Set 9 | azangaro
# Processing Record 26 of Set 9 | san patricio
# Processing Record 27 of Set 9 | perdoes
# Processing Record 28 of Set 9 | luanda
# Processing Record 29 of Set 9 | yumen
# Processing Record 30 of Set 9 | stevens point
# Processing Record 31 of Set 9 | north bend
# Processing Record 32 of Set 9 | independence
# Processing Record 33 of Set 9 | alappuzha
# Processing Record 34 of Set 9 | puerto leguizamo
# Processing Record 35 of Set 9 | bilibino
# Processing Record 36 of Set 9 | ahar
# Processing Record 37 of Set 9 | half moon bay
# Processing Record 38 of Set 9 | moen
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | matamoros
# Processing Record 41 of Set 9 | oxford
# Processing Record 42 of Set 9 | blagoyevo
# Processing Record 43 of Set 9 | tygda
# Processing Record 44 of Set 9 | qinhuangdao
# Processing Record 45 of Set 9 | alamosa
# Processing Record 46 of Set 9 | rio grande
# Processing Record 47 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 9 | mahajanga
# Processing Record 49 of Set 9 | thunder bay
# Processing Record 50 of Set 9 | taitung
# Processing Record 1 of Set 10 | na klang
# Processing Record 2 of Set 10 | binghamton
# Processing Record 3 of Set 10 | shimoda
# Processing Record 4 of Set 10 | kautokeino
# Processing Record 5 of Set 10 | namtsy
# Processing Record 6 of Set 10 | beloha
# Processing Record 7 of Set 10 | bantogon
# Processing Record 8 of Set 10 | sulina
# Processing Record 9 of Set 10 | peterhead
# Processing Record 10 of Set 10 | pierre
# Processing Record 11 of Set 10 | korsakov
# Processing Record 12 of Set 10 | rorvik
# Processing Record 13 of Set 10 | nome
# Processing Record 14 of Set 10 | houma
# Processing Record 15 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 16 of Set 10 | sosnovoborsk
# Processing Record 17 of Set 10 | moranbah
# Processing Record 18 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 10 | tromso
# Processing Record 20 of Set 10 | banda aceh
# Processing Record 21 of Set 10 | namalenga
# Processing Record 22 of Set 10 | tanout
# Processing Record 23 of Set 10 | aguimes
# Processing Record 24 of Set 10 | sao joao da barra
# Processing Record 25 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 10 | mama
# Processing Record 27 of Set 10 | baherden
# Processing Record 28 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 29 of Set 10 | labuhan
# Processing Record 30 of Set 10 | vaitape
# Processing Record 31 of Set 10 | roebourne
# Processing Record 32 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 10 | sao geraldo do araguaia
# Processing Record 34 of Set 10 | kalispell
# Processing Record 35 of Set 10 | jaumave
# Processing Record 36 of Set 10 | brae
# Processing Record 37 of Set 10 | jodhpur
# Processing Record 38 of Set 10 | dhidhdhoo
# Processing Record 39 of Set 10 | altay
# Processing Record 40 of Set 10 | wilhelmsburg
# Processing Record 41 of Set 10 | garden city
# Processing Record 42 of Set 10 | gigmoto
# Processing Record 43 of Set 10 | gniezno
# Processing Record 44 of Set 10 | dudinka
# Processing Record 45 of Set 10 | telemaco borba
# Processing Record 46 of Set 10 | sakhon nakhon
# Processing Record 47 of Set 10 | khovu-aksy
# Processing Record 48 of Set 10 | elat
# Processing Record 49 of Set 10 | dali
# Processing Record 50 of Set 10 | viet tri
# Processing Record 1 of Set 11 | yongan
# Processing Record 2 of Set 11 | port augusta
# Processing Record 3 of Set 11 | praia da vitoria
# Processing Record 4 of Set 11 | fukue
# Processing Record 5 of Set 11 | omboue
# Processing Record 6 of Set 11 | svetlogorsk
# Processing Record 7 of Set 11 | olivehurst
# Processing Record 8 of Set 11 | skjervoy
# Processing Record 9 of Set 11 | port blair
# Processing Record 10 of Set 11 | bloomfield
# Processing Record 11 of Set 11 | quelimane
# Processing Record 12 of Set 11 | nioki
# Processing Record 13 of Set 11 | aljezur
# Processing Record 14 of Set 11 | laguna
# Processing Record 15 of Set 11 | burila mare
# Processing Record 16 of Set 11 | bambanglipuro
# Processing Record 17 of Set 11 | churapcha
# Processing Record 18 of Set 11 | streator
# Processing Record 19 of Set 11 | keti bandar
# Processing Record 20 of Set 11 | usinsk
# Processing Record 21 of Set 11 | inhambane
# Processing Record 22 of Set 11 | orlik
# Processing Record 23 of Set 11 | kimbe
# Processing Record 24 of Set 11 | mandurah
# Processing Record 25 of Set 11 | hede
# Processing Record 26 of Set 11 | bilma
# Processing Record 27 of Set 11 | karasjok
# Processing Record 28 of Set 11 | ongandjera
# Processing Record 29 of Set 11 | djibo
# Processing Record 30 of Set 11 | baghdad
# Processing Record 31 of Set 11 | carutapera
# Processing Record 32 of Set 11 | giyon
# Processing Record 33 of Set 11 | disna
# Processing Record 34 of Set 11 | palora
# Processing Record 35 of Set 11 | burnie
# Processing Record 36 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 11 | jawhar
# Processing Record 39 of Set 11 | zambezi
# Processing Record 40 of Set 11 | hualmay
# Processing Record 41 of Set 11 | kemijarvi
# Processing Record 42 of Set 11 | megion
# Processing Record 43 of Set 11 | nantucket
# Processing Record 44 of Set 11 | kourou
# Processing Record 45 of Set 11 | bintulu
# Processing Record 46 of Set 11 | acarau
# Processing Record 47 of Set 11 | dharchula
# Processing Record 48 of Set 11 | alyangula
# Processing Record 49 of Set 11 | omsukchan
# Processing Record 50 of Set 11 | cedar city
# Processing Record 1 of Set 12 | mamontovo
# Processing Record 2 of Set 12 | can tho
# Processing Record 3 of Set 12 | lasa
# Processing Record 4 of Set 12 | yerofey pavlovich
# Processing Record 5 of Set 12 | sohag
# Processing Record 6 of Set 12 | la argentina
# Processing Record 7 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 12 | liuzhou
# Processing Record 9 of Set 12 | pilar
# Processing Record 10 of Set 12 | rawatbhata
# Processing Record 11 of Set 12 | tombouctou
# Processing Record 12 of Set 12 | acapulco
# Processing Record 13 of Set 12 | general roca
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | rodrigues alves
# Processing Record 16 of Set 12 | urusha
# Processing Record 17 of Set 12 | taylorville
# Processing Record 18 of Set 12 | kloulklubed
# Processing Record 19 of Set 12 | jega
# Processing Record 20 of Set 12 | ust-ilimsk
# Processing Record 21 of Set 12 | salalah
# Processing Record 22 of Set 12 | shwebo
# Processing Record 23 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 12 | okha
# Processing Record 25 of Set 12 | hobyo
# Processing Record 26 of Set 12 | fort oglethorpe
# Processing Record 27 of Set 12 | bima
# Processing Record 28 of Set 12 | lincoln
# Processing Record 29 of Set 12 | ballia
# Processing Record 30 of Set 12 | pelasyia
# City not found. Skipping...
# Processing Record 31 of Set 12 | smithers
# Processing Record 32 of Set 12 | lashio
# Processing Record 33 of Set 12 | sainte-suzanne
# Processing Record 34 of Set 12 | tambopata
# Processing Record 35 of Set 12 | pusad
# Processing Record 36 of Set 12 | aliwal north
# Processing Record 37 of Set 12 | shahabad
# Processing Record 38 of Set 12 | springbok
# Processing Record 39 of Set 12 | gilgit
# Processing Record 40 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 12 | bobonong
# City not found. Skipping...
# Processing Record 42 of Set 12 | stromness
# Processing Record 43 of Set 12 | khasan
# Processing Record 44 of Set 12 | si sa ket
# Processing Record 45 of Set 12 | mandeville
# Processing Record 46 of Set 12 | montrose
# Processing Record 47 of Set 12 | bonavista
# Processing Record 48 of Set 12 | aranos
# Processing Record 49 of Set 12 | dicabisagan
# Processing Record 50 of Set 12 | high level
# Processing Record 1 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 13 | olinda
# Processing Record 4 of Set 13 | srednekolymsk
# Processing Record 5 of Set 13 | brajrajnagar
# City not found. Skipping...
# Processing Record 6 of Set 13 | olga
# Processing Record 7 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 13 | oksfjord
# Processing Record 9 of Set 13 | ixtapa
# Processing Record 10 of Set 13 | edd
# Processing Record 11 of Set 13 | molepolole
# Processing Record 12 of Set 13 | baykit
# Processing Record 13 of Set 13 | fairview
# Processing Record 14 of Set 13 | ust-kuyga
# Processing Record 15 of Set 13 | talnakh
# Processing Record 16 of Set 13 | lithakia
# Processing Record 17 of Set 13 | port shepstone
# Processing Record 18 of Set 13 | simao
# Processing Record 19 of Set 13 | finschhafen
# Processing Record 20 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 13 | oranjemund
# Processing Record 22 of Set 13 | portland
# Processing Record 23 of Set 13 | toora-khem
# Processing Record 24 of Set 13 | vao
# Processing Record 25 of Set 13 | kantang
# Processing Record 26 of Set 13 | sakaiminato
# Processing Record 27 of Set 13 | ewa beach
# Processing Record 28 of Set 13 | qandala
# Processing Record 29 of Set 13 | kez
# Processing Record 30 of Set 13 | maraa
# Processing Record 31 of Set 13 | itaituba
# Processing Record 32 of Set 13 | maceio
# Processing Record 33 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 13 | pyay
# Processing Record 35 of Set 13 | abapo
# Processing Record 36 of Set 13 | kenai
# Processing Record 37 of Set 13 | balsas
# Processing Record 38 of Set 13 | sorland
# Processing Record 39 of Set 13 | linqing
# Processing Record 40 of Set 13 | faya
# Processing Record 41 of Set 13 | dera bugti
# Processing Record 42 of Set 13 | cuamba
# Processing Record 43 of Set 13 | lianran
# Processing Record 44 of Set 13 | berlevag
# Processing Record 45 of Set 13 | mae sai
# Processing Record 46 of Set 13 | wakkanai
# Processing Record 47 of Set 13 | juneau
# Processing Record 48 of Set 13 | kitob
# Processing Record 49 of Set 13 | george
# Processing Record 50 of Set 13 | batsfjord
# Processing Record 1 of Set 14 | foldeak
# Processing Record 2 of Set 14 | roald
# Processing Record 3 of Set 14 | zhezkazgan
# Processing Record 4 of Set 14 | turukhansk
# Processing Record 5 of Set 14 | dongying
# Processing Record 6 of Set 14 | udachnyy
# Processing Record 7 of Set 14 | eenhana
# Processing Record 8 of Set 14 | huancavelica
# Processing Record 9 of Set 14 | serdobsk
# Processing Record 10 of Set 14 | nago
# Processing Record 11 of Set 14 | vangaindrano
# Processing Record 12 of Set 14 | valle de allende
# Processing Record 13 of Set 14 | wakefield
# Processing Record 14 of Set 14 | ternate
# Processing Record 15 of Set 14 | honiara
# Processing Record 16 of Set 14 | kemi
# Processing Record 17 of Set 14 | sobolevo
# Processing Record 18 of Set 14 | charlestown
# Processing Record 19 of Set 14 | soverato
# Processing Record 20 of Set 14 | formiga
# Processing Record 21 of Set 14 | aksu
# Processing Record 22 of Set 14 | karratha
# Processing Record 23 of Set 14 | khanu woralaksaburi
# Processing Record 24 of Set 14 | bitung
# Processing Record 25 of Set 14 | inta
# Processing Record 26 of Set 14 | sao jose da coroa grande
# Processing Record 27 of Set 14 | reinosa
# Processing Record 28 of Set 14 | zhumadian
# Processing Record 29 of Set 14 | derzhavinsk
# Processing Record 30 of Set 14 | nyurba
# Processing Record 31 of Set 14 | magadan
# Processing Record 32 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 33 of Set 14 | san andres
# Processing Record 34 of Set 14 | cataingan
# Processing Record 35 of Set 14 | kushima
# Processing Record 36 of Set 14 | aswan
# Processing Record 37 of Set 14 | hasaki
# Processing Record 38 of Set 14 | high rock
# Processing Record 39 of Set 14 | mantua
# Processing Record 40 of Set 14 | komsomolskiy
# Processing Record 41 of Set 14 | zhigansk
# Processing Record 42 of Set 14 | amarkantak
# Processing Record 43 of Set 14 | henties bay
# Processing Record 44 of Set 14 | coxim
# Processing Record 45 of Set 14 | maningrida
# Processing Record 46 of Set 14 | ambunti
# Processing Record 47 of Set 14 | san quintin
# Processing Record 48 of Set 14 | ilo
# Processing Record 49 of Set 14 | saint anthony
# Processing Record 50 of Set 14 | sangar
# Processing Record 1 of Set 15 | sierre
# Processing Record 2 of Set 15 | roma
# Processing Record 3 of Set 15 | panaba
# Processing Record 4 of Set 15 | severo-yeniseyskiy
# Processing Record 5 of Set 15 | pangoa
# Processing Record 6 of Set 15 | bodden town
# Processing Record 7 of Set 15 | babol
# Processing Record 8 of Set 15 | anloga
# Processing Record 9 of Set 15 | hopfgarten
# Processing Record 10 of Set 15 | iracoubo
# Processing Record 11 of Set 15 | labuan
# Processing Record 12 of Set 15 | asasa
# Processing Record 13 of Set 15 | preobrazheniye
# Processing Record 14 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 15 of Set 15 | yatou
# Processing Record 16 of Set 15 | shitanjing
# Processing Record 17 of Set 15 | ribas do rio pardo
# Processing Record 18 of Set 15 | saint-denis
# Processing Record 19 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 20 of Set 15 | avera
# Processing Record 21 of Set 15 | eyrarbakki
# Processing Record 22 of Set 15 | saint-georges
# Processing Record 23 of Set 15 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 671 non-null    object
#  1   Country              671 non-null    object
#  2   Lat                  671 non-null    float64
#  3   Lng                  671 non-null    float64
#  4   Max Temp             671 non-null    float64
#  5   Humidity             671 non-null    int64
#  6   Cloudiness           671 non-null    int64
#  7   Wind Speed           671 non-null    float64
#  8   Current Description  671 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 47.3+ KB

# %%
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Khani      GE  41.9563   42.9566     63.97        98         100
# 1          Atar      MR  20.5169  -13.0499     99.73        24           0
# 2   Yerbogachen      RU  61.2767  108.0108     51.28        94          36
# 3      Kamaishi      JP  39.2667  141.8833     69.40        96         100
# 4  Punta Arenas      CL -53.1500  -70.9167     33.91        93         100
#
#    Wind Speed Current Description
# 0        2.46          light rain
# 1       13.65           clear sky
# 2        4.38    scattered clouds
# 3       10.92     overcast clouds
# 4        9.22          light snow

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
